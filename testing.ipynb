# %%
brew install cairo pkg-config tcl-tk python-tk
# Out:
#   Cell In[3], line 1
#     brew install cairo pkg-config tcl-tk python-tk
#          ^
# SyntaxError: invalid syntax

# %%
from niftiview import TEMPLATES, NiftiImage

nii = NiftiImage()
# nii = NiftiImage('/path/to/your/nifti.nii.gz')
im = nii.get_image()
im.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from niftiview import TEMPLATES, NiftiImage
#       3 nii = NiftiImage()
#       4 # nii = NiftiImage('/path/to/your/nifti.nii.gz')
#
# ModuleNotFoundError: No module named 'niftiview'
